# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("retail_sales_dataset.csv")

# %%
df.head()
# Out:
#   transaction_id transaction_date customer_id customer_gender  \
# 0       T0000001       2024-04-24     C000820           Other
# 1       T0000002       2025-07-12     C002849           Other
# 2       T0000003       2025-06-01     C019727            Male
# 3       T0000004       2025-08-26     C009116            Male
# 4       T0000005       2024-12-10     C003350            Male
#
#   customer_age_group customer_segment product_id   product_name  category  \
# 0              35-44        Returning      P1082      Dumbbells    Sports
# 1              45-54              New      P1087  Running Shoes    Sports
# 2                55+        Returning      P1030       Sneakers  Clothing
# 3              25-34              VIP      P1058      Sunscreen    Beauty
# 4              45-54              New      P1028       Sneakers  Clothing
#
#      brand  quantity  unit_price  discount_pct  sales_amount payment_method  \
# ...

# %%
df.shape
# Out:
# (120000, 17)

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'customer_id', 'customer_gender',
#        'customer_age_group', 'customer_segment', 'product_id', 'product_name',
#        'category', 'brand', 'quantity', 'unit_price', 'discount_pct',
#        'sales_amount', 'payment_method', 'sales_channel', 'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# transaction_id         object
# transaction_date       object
# customer_id            object
# customer_gender        object
# customer_age_group     object
# customer_segment       object
# product_id             object
# product_name           object
# category               object
# brand                  object
# quantity                int64
# unit_price            float64
# discount_pct            int64
# sales_amount          float64
# payment_method         object
# sales_channel          object
# region                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction_id      120000 non-null  object
#  1   transaction_date    120000 non-null  object
#  2   customer_id         120000 non-null  object
#  3   customer_gender     120000 non-null  object
#  4   customer_age_group  120000 non-null  object
#  5   customer_segment    120000 non-null  object
#  6   product_id          120000 non-null  object
#  7   product_name        120000 non-null  object
#  8   category            120000 non-null  object
#  9   brand               120000 non-null  object
#  10  quantity            120000 non-null  int64
#  11  unit_price          120000 non-null  float64
#  12  discount_pct        120000 non-null  int64
#  13  sales_amount        120000 non-null  float64
#  14  payment_method      120000 non-null  object
# ...

# %%
df.describe()
# Out:
#             quantity     unit_price   discount_pct   sales_amount
# count  120000.000000  120000.000000  120000.000000  120000.000000
# mean        1.662908     240.621785       5.496500     377.975454
# std         1.014291     146.457057       8.193257     356.893357
# min         1.000000       7.730000       0.000000       5.410000
# 25%         1.000000     102.010000       0.000000     136.860000
# 50%         1.000000     238.750000       0.000000     295.980000
# 75%         2.000000     379.000000      10.000000     461.500000
# max         5.000000     493.510000      30.000000    2467.550000

# %%
df.isnull().sum()
# Out:
# transaction_id        0
# transaction_date      0
# customer_id           0
# customer_gender       0
# customer_age_group    0
# customer_segment      0
# product_id            0
# product_name          0
# category              0
# brand                 0
# quantity              0
# unit_price            0
# discount_pct          0
# sales_amount          0
# payment_method        0
# sales_channel         0
# region                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# transaction_id        120000
# transaction_date         730
# customer_id            24784
# customer_gender            3
# customer_age_group         5
# customer_segment           4
# product_id               120
# product_name              40
# category                   8
# brand                      3
# quantity                   5
# unit_price               120
# discount_pct               7
# sales_amount            3682
# payment_method             5
# sales_channel              3
# region                     5
# dtype: int64

# %%
df["region"].unique()
# Out:
# array(['North', 'South', 'Central', 'East', 'West'], dtype=object)

# %%
df["sales_channel"].unique()
# Out:
# array(['Online', 'In-Store', 'Mobile App'], dtype=object)

# %%
df["payment_method"].unique()
# Out:
# array(['Debit Card', 'Credit Card', 'Gift Card', 'Cash', 'PayPal'],
#       dtype=object)

# %%
df["brand"].unique()
# Out:
# array(['Brand 1', 'Brand 3', 'Brand 2'], dtype=object)

# %%
df["category"].unique()
# Out:
# array(['Sports', 'Clothing', 'Beauty', 'Groceries', 'Toys', 'Home',
#        'Books', 'Electronics'], dtype=object)

# %%
df["customer_segment"].unique()
# Out:
# array(['Returning', 'New', 'VIP', 'Loyal'], dtype=object)

# %%
df["customer_age_group"].unique()
# Out:
# array(['35-44', '45-54', '55+', '25-34', '18-24'], dtype=object)

# %%
df["customer_gender"].unique()
# Out:
# array(['Other', 'Male', 'Female'], dtype=object)

# %%
df["customer_segment"].value_counts()
# Out:
# customer_segment
# VIP          30115
# New          30020
# Loyal        30014
# Returning    29851
# Name: count, dtype: int64

# %%
df["payment_method"].value_counts()
# Out:
# payment_method
# Credit Card    24262
# Cash           24034
# PayPal         23998
# Debit Card     23897
# Gift Card      23809
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# Central    24244
# North      24075
# South      24066
# West       23950
# East       23665
# Name: count, dtype: int64

# %%
df["sales_channel"].value_counts()
# Out:
# sales_channel
# Mobile App    40204
# In-Store      40049
# Online        39747
# Name: count, dtype: int64

# %%
df["category"].value_counts()
# Out:
# category
# Sports         15218
# Clothing       15156
# Beauty         15073
# Groceries      15034
# Toys           15022
# Electronics    15008
# Home           14933
# Books          14556
# Name: count, dtype: int64

# %%
df["brand"].value_counts()
# Out:
# brand
# Brand 1    40240
# Brand 2    39918
# Brand 3    39842
# Name: count, dtype: int64

# %%
df["customer_gender"].value_counts()
# Out:
# customer_gender
# Female    40268
# Other     39906
# Male      39826
# Name: count, dtype: int64

# %%
df["customer_age_group"].value_counts()
# Out:
# customer_age_group
# 35-44    24196
# 55+      24078
# 18-24    23941
# 45-54    23919
# 25-34    23866
# Name: count, dtype: int64

# %%
df.groupby("customer_segment")["sales_amount"].sum()
# Out:
# customer_segment
# Loyal        11393721.23
# New          11331906.60
# Returning    11311255.31
# VIP          11320171.31
# Name: sales_amount, dtype: float64

# %%
df.groupby("region")["quantity"].sum()
# Out:
# region
# Central    40617
# East       39293
# North      39935
# South      39852
# West       39852
# Name: quantity, dtype: int64

# %%
df.groupby("region")["quantity"].mean()
# Out:
# region
# Central    1.675342
# East       1.660385
# North      1.658775
# South      1.655946
# West       1.663967
# Name: quantity, dtype: float64

# %%
df.groupby("region")["quantity"].max()
# Out:
# region
# Central    5
# East       5
# North      5
# South      5
# West       5
# Name: quantity, dtype: int64

# %%
df.groupby("region")["quantity"].min()
# Out:
# region
# Central    1
# East       1
# North      1
# South      1
# West       1
# Name: quantity, dtype: int64

# %%
df.groupby("region")["quantity"].count()
# Out:
# region
# Central    24244
# East       23665
# North      24075
# South      24066
# West       23950
# Name: quantity, dtype: int64

# %%
df.groupby("region")["quantity"].sum().sort_values(ascending=False)
# Out:
# region
# Central    40617
# North      39935
# South      39852
# West       39852
# East       39293
# Name: quantity, dtype: int64

# %%
df.groupby("region")["quantity"].agg(["sum", "mean"])
# Out:
#            sum      mean
# region
# Central  40617  1.675342
# East     39293  1.660385
# North    39935  1.658775
# South    39852  1.655946
# West     39852  1.663967

# %%
df.groupby(["region", "customer_segment"])["sales_amount"].sum()
# Out:
# region   customer_segment
# Central  Loyal               2308975.89
#          New                 2297284.65
#          Returning           2308500.27
#          VIP                 2323163.30
# East     Loyal               2266017.59
#          New                 2271531.17
#          Returning           2194164.14
#          VIP                 2239804.74
# North    Loyal               2289354.84
#          New                 2232237.10
#          Returning           2263930.46
#          VIP                 2263915.71
# South    Loyal               2256868.05
#          New                 2288675.89
#          Returning           2219145.90
#          VIP                 2226573.05
# West     Loyal               2272504.86
#          New                 2242177.79
#          Returning           2325514.54
#          VIP                 2266714.51
# Name: sales_amount, dtype: float64

# %%
brand_discount = df.groupby("brand")["discount_pct"].mean()
brand_discount[brand_discount > 20]
# Out:
# Series([], Name: discount_pct, dtype: float64)

# %%
df.groupby("region")["sales_amount"].sum().reset_index()
# Out:
#     region  sales_amount
# 0  Central    9237924.11
# 1     East    8971517.64
# 2    North    9049438.11
# 3    South    8991262.89
# 4     West    9106911.70

# %%
pd.pivot_table(
    df,
    index="region",
    columns="customer_segment",
    values="sales_amount",
    aggfunc="sum",
    fill_value=0
)
# Out:
# customer_segment       Loyal         New   Returning         VIP
# region
# Central           2308975.89  2297284.65  2308500.27  2323163.30
# East              2266017.59  2271531.17  2194164.14  2239804.74
# North             2289354.84  2232237.10  2263930.46  2263915.71
# South             2256868.05  2288675.89  2219145.90  2226573.05
# West              2272504.86  2242177.79  2325514.54  2266714.51

# %%
pd.pivot_table(
    df,
    index="category",
    columns="sales_channel",
    values="sales_amount",
    aggfunc="sum",
    fill_value=0
)
# Out:
# sales_channel    In-Store  Mobile App      Online
# category
# Beauty         2119700.91  2118470.10  2117547.22
# Books          2080189.39  1948978.04  1976070.26
# Clothing       1552238.04  1572905.65  1503235.76
# Electronics    1973856.07  1952558.05  1933272.57
# Groceries      1860771.69  1786099.82  1784665.13
# Home           1846759.42  1869617.50  1939185.88
# Sports         2004944.32  1953770.12  1904656.32
# Toys           1834766.43  1863584.10  1859211.66

# %%
pd.pivot_table(
    df,
    index="brand",
    columns="customer_segment",
    values="discount_pct",
    aggfunc="mean",
    fill_value=0
)
# Out:
# customer_segment     Loyal       New  Returning       VIP
# brand
# Brand 1           5.489555  5.474565   5.454545  5.477282
# Brand 2           5.604940  5.473216   5.556678  5.402976
# Brand 3           5.461562  5.417255   5.650492  5.495728

# %%
region_sales = df.groupby("region", as_index=False)["sales_amount"].sum()
plt.figure(figsize=(8,5))
plt.bar(region_sales["region"], region_sales["sales_amount"])
plt.title("Total Revenue by Region")
plt.xlabel("Region")
plt.ylabel("Revenue")
plt.show()

# %%
segment_sales = df.groupby("customer_segment", as_index=False)["sales_amount"].sum()

plt.figure(figsize=(8,5))
plt.bar(segment_sales["customer_segment"], segment_sales["sales_amount"])
plt.title("Revenue by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Revenue")
plt.show()

# %%
category_sales = df.groupby("category", as_index=False)["sales_amount"].sum().sort_values(
    by="sales_amount",
    ascending=False
)

plt.figure(figsize=(10,5))
plt.bar(category_sales["category"], category_sales["sales_amount"])
plt.title("Revenue by Product Category")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["discount_pct"], bins=10)
plt.title("Distribution of Discounts")
plt.xlabel("Discount Percentage")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df["sales_amount"])
plt.title("Sales Amount Distribution")
plt.ylabel("Sales Amount")
plt.show()
